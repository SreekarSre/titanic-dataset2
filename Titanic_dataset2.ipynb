# %%
titanic = sns.load_dataset('titanic')

titanic.to_csv('titanic.csv', index=False)

# %% [markdown]
# Load the necessary libraries and dataset

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

display(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Clean the dataset

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
df.drop(columns=["deck"], inplace=True)

# %% [markdown]
# Create Age Groups

# %%
df["AgeGroup"] = pd.cut(df["age"], bins=[0, 12, 18, 30, 50, 80], labels=["Child", "Teen", "YoungAdult", "Adult", "Senior"])

# %% [markdown]
# Analyze Survival Rate by Age Group

# %%
sns.barplot(x="AgeGroup", y="survived", data=df)
plt.title("Survival Rate by Age Group")
plt.show()

# %% [markdown]
# Analyze Survival Rate by Embarkation Port

# %%
survival_rate_by_embarkation = df.groupby("embarked")["survived"].mean()
print(survival_rate_by_embarkation)
# Out:
# embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: survived, dtype: float64

# %%
sns.barplot(x=survival_rate_by_embarkation.index, y=survival_rate_by_embarkation.values)
plt.title("Survival Rate by Embarkation Port")
plt.show()

# %% [markdown]
#  Analyze Survival Rate by Family Size

# %%
df["FamilySize"] = df["sibsp"] + df["parch"]

# %% [markdown]
# Create Visualizations

# %%
sns.barplot(x="FamilySize", y="survived", data=df)
plt.title("Survival Rate by Family Size")
plt.show()

# %%
sns.histplot(df["age"], bins= 20)
plt.title("Age Distribution")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Deliverable

# %% [markdown]
# Create a colab Notebook with the cleaned data, multiple insights, and professional visualizations.
